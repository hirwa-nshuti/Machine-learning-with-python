# %% [markdown]
# # Regression With Keras D

# %% [markdown]
# ## Table of content

# %% [markdown]
# 1. Data Viualization
# 2. Data preprocessing
# 3.Model Building
# 4.Model Training
# 5.Model Evaluation
# 6.MSE mean and std calculation

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Importing the required Libraries

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# Dataset Loading

# %%
data=pd.read_csv("concrete_data.csv")
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# Checking for null values

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# Spliting the dataset into predicting variables and target ones

# %%
target_variables=data["Strength"]
predicting_variables=data[["Cement","Blast Furnace Slag", "Fly Ash","Water",
                         "Superplasticizer", "Coarse Aggregate", "Fine Aggregate", "Age"]]
predicting_variables.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target_variables.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Normalization for predicting variables

# %%
predicting_val=(predicting_variables-predicting_variables.mean())/predicting_variables.std()
predicting_val.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Creating ncols as we are going to need it in building our model

# %%
ncols=predicting_val.shape[1]

# %% [markdown]
# ### Now we are good to build our model

# %% [markdown]
# As we've imorted all required libraries at the top we are going to build our model

# %% [markdown]
# Defining the model function

# %%
def regression_model():
    
    #Build the model
    model=Sequential()
    model.add(Dense(10,activation="relu", input_shape=(ncols,)))
    model.add(Dense(10,activation="relu"))
    model.add(Dense(10,activation="relu"))
    model.add(Dense(1))
    
    #compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Training the Model

# %%
model=regression_model()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( predicting_val, target_variables, test_size=0.3, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# fit the model
model.fit(predicting_val, target_variables, validation_split=0.3, epochs=100, verbose=1)
# Out:
# Train set: (721, 8) (721,)
# Test set: (309, 8) (309,)
# Train on 721 samples, validate on 309 samples
# Epoch 1/100
# 721/721 [==============================] - 1s 1ms/step - loss: 1749.4496 - val_loss: 1245.3518
# Epoch 2/100
# 721/721 [==============================] - 0s 502us/step - loss: 1720.4723 - val_loss: 1232.4528
# Epoch 3/100
# 721/721 [==============================] - 0s 467us/step - loss: 1697.2184 - val_loss: 1219.3701
# Epoch 4/100
# 721/721 [==============================] - 0s 583us/step - loss: 1671.4552 - val_loss: 1200.2196
# Epoch 5/100
# 721/721 [==============================] - 0s 520us/step - loss: 1636.2503 - val_loss: 1170.8498
# Epoch 6/100
# 721/721 [==============================] - 0s 497us/step - loss: 1584.9733 - val_loss: 1128.2552
# Epoch 7/100
# 721/721 [==============================] - 0s 501us/step - loss: 1510.2876 - val_loss: 1068.1673
# Epoch 8/100
# 721/721 [==============================] - 0s 463us/step - loss: 1401.5114 - val_loss: 987.3124
# Epoch 9/100
# 721/721 [==============================] - 0s 449us/step - loss: 1254.5242 - val_loss: 881.4589
# Epoch 10/100
# 721/721 [==============================] - 0s 441us/step - loss: 1067.6318 - val_loss: 753.7195
# Epoch 11/100
# 721/721 [==============================] - 0s 457us/step - loss: 852.7835 - val_loss: 611.6791
# Epoch 12/100
# 721/721 [==============================] - 0s 448us/step - loss: 636.4686 - val_loss: 475.6021
# Epoch 13/100
# 721/721 [==============================] - 0s 415us/step - loss: 461.1897 - val_loss: 376.5523
# Epoch 14/100
# 721/721 [==============================] - 0s 420us/step - loss: 353.3036 - val_loss: 313.9594
# Epoch 15/100
# 721/721 [==============================] - 0s 460us/step - loss: 292.9814 - val_loss: 268.8462
# Epoch 80/100
# 721/721 [==============================] - 0s 521us/step - loss: 109.5943 - val_loss: 114.6853
# Epoch 81/100
# 721/721 [==============================] - 0s 660us/step - loss: 108.6797 - val_loss: 115.4121
# Epoch 82/100
# 721/721 [==============================] - 0s 495us/step - loss: 108.1176 - val_loss: 112.1845
# Epoch 83/100
# 721/721 [==============================] - 0s 472us/step - loss: 107.6791 - val_loss: 112.1344
# Epoch 84/100
# 721/721 [==============================] - 0s 474us/step - loss: 107.2080 - val_loss: 112.6834
# Epoch 85/100
# 721/721 [==============================] - 0s 523us/step - loss: 106.4884 - val_loss: 111.9540
# Epoch 86/100
# 721/721 [==============================] - 0s 525us/step - loss: 106.0147 - val_loss: 111.8545
# Epoch 87/100
# 721/721 [==============================] - 0s 557us/step - loss: 105.4310 - val_loss: 111.2788
# Epoch 88/100
# 721/721 [==============================] - 0s 671us/step - loss: 104.8132 - val_loss: 110.3386
# Epoch 89/100
# 721/721 [==============================] - 0s 498us/step - loss: 104.6335 - val_loss: 109.2258
# Epoch 90/100
# 721/721 [==============================] - 0s 521us/step - loss: 103.8945 - val_loss: 109.4939
# Epoch 91/100
# 721/721 [==============================] - 0s 504us/step - loss: 103.6381 - val_loss: 108.5439
# Epoch 92/100
# 721/721 [==============================] - 0s 464us/step - loss: 103.0106 - val_loss: 109.0964
# Epoch 93/100
# 721/721 [==============================] - 0s 502us/step - loss: 102.3885 - val_loss: 107.9444
# Epoch 94/100
# 721/721 [==============================] - 0s 497us/step - loss: 101.7661 - val_loss: 108.0460
# Epoch 95/100
# 721/721 [==============================] - 0s 465us/step - loss: 101.0278 - val_loss: 106.4940
# Epoch 96/100
# 721/721 [==============================] - 0s 419us/step - loss: 100.7960 - val_loss: 105.4170
# Epoch 97/100
# 721/721 [==============================] - 0s 472us/step - loss: 99.9637 - val_loss: 104.6954
# Epoch 98/100
# 721/721 [==============================] - 0s 446us/step - loss: 99.7198 - val_loss: 104.5916
# Epoch 99/100
# 721/721 [==============================] - 0s 582us/step - loss: 99.6770 - val_loss: 102.6369
# Epoch 100/100
# 721/721 [==============================] - 0s 445us/step - loss: 98.4572 - val_loss: 101.7856

# %%
loss_val = model.evaluate(X_test, y_test)
yhat = model.predict(X_test)
loss_val
# Out:
# 309/309 [==============================] - 0s 192us/step
# 105.54553000440875

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import mean_squared_error
#Mean and std calculation for mse
mse = mean_squared_error(y_test, yhat)
mean = np.mean(mse)
standard_deviation = np.std(mse)
print("Mean of mse is: ",mean,"and STD of mse is: ", standard_deviation)
# Out:
# Mean of mse is:  105.54553374704675 and STD of mse is:  0.0

# %%
total_errors = 100
epochs = 100
mean_squared_errors = []
for i in range(0, total_errors):
    X_train, X_test, y_train, y_test = train_test_split(predicting_val, target_variables, test_size=0.3, random_state=i)
    model.fit(X_train, y_train, epochs=epochs, verbose=0)
    MSE = model.evaluate(X_test, y_test, verbose=0)
    print("MSE "+str(i+1)+": "+str(MSE))
    yhat = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, yhat)
    mean_squared_errors.append(mean_square_error)

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
standard_deviation = np.std(mean_squared_errors)

print('\n