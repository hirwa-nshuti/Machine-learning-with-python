# %% [markdown]
# # Regression With Keras C

# %% [markdown]
# ## Table of content

# %% [markdown]
# 1. Data Viualization
# 2. Data preprocessing
# 3.Model Building
# 4.Model Training
# 5.Model Evaluation
# 6.MSE mean and std calculation

# %% [markdown]
# Data Cleaning and preprocessing

# %% [markdown]
# Importing the required Libraries

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# Dataset Loading

# %%
data=pd.read_csv("concrete_data.csv")
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# Checking for null values

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# Spliting the dataset into predicting variables and target ones

# %%
target_variables=data["Strength"]
predicting_variables=data[["Cement","Blast Furnace Slag", "Fly Ash","Water",
                         "Superplasticizer", "Coarse Aggregate", "Fine Aggregate", "Age"]]
predicting_variables.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target_variables.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Normalization for predicting variables

# %%
predicting_val=(predicting_variables-predicting_variables.mean())/predicting_variables.std()
predicting_val.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Creating ncols as we are going to need it in building our model

# %%
ncols=predicting_val.shape[1]

# %% [markdown]
# ### Now we are good to build our model

# %% [markdown]
# As we've imorted all required libraries at the top we are going to build our model

# %% [markdown]
# Defining the model function

# %%
def regression_model():
    
    #Build the model
    model=Sequential()
    model.add(Dense(10,activation="relu", input_shape=(ncols,)))
    model.add(Dense(1))
    
    #compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Training the Model

# %%
model=regression_model()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( predicting_val, target_variables, test_size=0.3, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# fit the model
model.fit(predicting_val, target_variables, validation_split=0.3, epochs=100, verbose=1)
# Out:
# Train set: (721, 8) (721,)
# Test set: (309, 8) (309,)
# Train on 721 samples, validate on 309 samples
# Epoch 1/100
# 721/721 [==============================] - 1s 833us/step - loss: 1738.0375 - val_loss: 1241.6273
# Epoch 2/100
# 721/721 [==============================] - 0s 314us/step - loss: 1719.2123 - val_loss: 1229.2188
# Epoch 3/100
# 721/721 [==============================] - 0s 305us/step - loss: 1701.1820 - val_loss: 1216.9555
# Epoch 4/100
# 721/721 [==============================] - 0s 361us/step - loss: 1683.2107 - val_loss: 1204.9521
# Epoch 5/100
# 721/721 [==============================] - 0s 418us/step - loss: 1664.9753 - val_loss: 1192.7845
# Epoch 6/100
# 721/721 [==============================] - 0s 385us/step - loss: 1646.2136 - val_loss: 1180.2742
# Epoch 7/100
# 721/721 [==============================] - 0s 387us/step - loss: 1626.4419 - val_loss: 1167.3438
# Epoch 8/100
# 721/721 [==============================] - 0s 354us/step - loss: 1605.6873 - val_loss: 1153.3603
# Epoch 9/100
# 721/721 [==============================] - 0s 336us/step - loss: 1583.8020 - val_loss: 1138.9988
# Epoch 10/100
# 721/721 [==============================] - 0s 396us/step - loss: 1560.5723 - val_loss: 1123.6097
# Epoch 11/100
# 721/721 [==============================] - 0s 572us/step - loss: 1535.5045 - val_loss: 1107.5323
# Epoch 12/100
# 721/721 [==============================] - 0s 336us/step - loss: 1509.3987 - val_loss: 1090.2370
# Epoch 13/100
# 721/721 [==============================] - 0s 413us/step - loss: 1481.1919 - val_loss: 1072.5984
# Epoch 14/100
# 721/721 [==============================] - 0s 445us/step - loss: 1451.9271 - val_loss: 1054.0094
# Epoch 15/100
# 721/721 [==============================] - 0s 518us/step - loss: 1421.2912 - val_loss: 1034.5955
# Epoch 16/100
# Epoch 80/100
# 721/721 [==============================] - 0s 360us/step - loss: 212.5832 - val_loss: 247.6454
# Epoch 81/100
# 721/721 [==============================] - 0s 392us/step - loss: 211.1132 - val_loss: 246.0426
# Epoch 82/100
# 721/721 [==============================] - 0s 631us/step - loss: 209.5985 - val_loss: 245.1191
# Epoch 83/100
# 721/721 [==============================] - 0s 388us/step - loss: 208.2508 - val_loss: 244.2672
# Epoch 84/100
# 721/721 [==============================] - 0s 357us/step - loss: 206.8795 - val_loss: 243.2153
# Epoch 85/100
# 721/721 [==============================] - 0s 329us/step - loss: 205.6504 - val_loss: 242.7623
# Epoch 86/100
# 721/721 [==============================] - 0s 339us/step - loss: 204.3281 - val_loss: 241.9436
# Epoch 87/100
# 721/721 [==============================] - 0s 384us/step - loss: 203.1892 - val_loss: 240.4512
# Epoch 88/100
# 721/721 [==============================] - 0s 360us/step - loss: 201.9788 - val_loss: 240.0114
# Epoch 89/100
# 721/721 [==============================] - 0s 329us/step - loss: 200.7955 - val_loss: 239.3302
# Epoch 90/100
# 721/721 [==============================] - 0s 476us/step - loss: 199.6451 - val_loss: 238.8693
# Epoch 91/100
# 721/721 [==============================] - 1s 757us/step - loss: 198.6305 - val_loss: 237.7841
# Epoch 92/100
# 721/721 [==============================] - 0s 339us/step - loss: 197.6211 - val_loss: 237.2387
# Epoch 93/100
# 721/721 [==============================] - 0s 407us/step - loss: 196.5505 - val_loss: 236.5284
# Epoch 94/100
# 721/721 [==============================] - 0s 499us/step - loss: 195.5804 - val_loss: 235.5926
# Epoch 95/100
# 721/721 [==============================] - 0s 307us/step - loss: 194.6016 - val_loss: 234.6392
# Epoch 96/100
# 721/721 [==============================] - 0s 450us/step - loss: 193.6977 - val_loss: 234.0456
# Epoch 97/100
# 721/721 [==============================] - 0s 402us/step - loss: 192.7195 - val_loss: 233.2367
# Epoch 98/100
# 721/721 [==============================] - 0s 333us/step - loss: 191.8387 - val_loss: 232.3011
# Epoch 99/100
# 721/721 [==============================] - 0s 331us/step - loss: 190.9011 - val_loss: 231.7086
# Epoch 100/100
# 721/721 [==============================] - 0s 392us/step - loss: 190.1236 - val_loss: 231.3000

# %%
loss_val = model.evaluate(X_test, y_test)
yhat = model.predict(X_test)
loss_val
# Out:
# 309/309 [==============================] - 0s 188us/step
# 211.99146974433972

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import mean_squared_error
#Mean and std calculation for mse
mse = mean_squared_error(y_test, yhat)
mean = np.mean(mse)
standard_deviation = np.std(mse)
print("Mean of mse is: ",mean,"and STD of mse is: ", standard_deviation)
# Out:
# Mean of mse is:  211.99146895211265 and STD of mse is:  0.0

# %%
total_errors = 100
epochs = 100
mean_squared_errors = []
for i in range(0, total_errors):
    X_train, X_test, y_train, y_test = train_test_split(predicting_val, target_variables, test_size=0.3, random_state=i)
    model.fit(X_train, y_train, epochs=epochs, verbose=0)
    MSE = model.evaluate(X_test, y_test, verbose=0)
    print("MSE "+str(i+1)+": "+str(MSE))
    yhat = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, yhat)
    mean_squared_errors.append(mean_square_error)

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
standard_deviation = np.std(mean_squared_errors)

print('\n